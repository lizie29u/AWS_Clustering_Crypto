# %% [markdown]
# # Clustering Crypto

# %%
# !pip install -U altair
# Out:
# Requirement already up-to-date: altair in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (4.1.0)
# Requirement already satisfied, skipping upgrade: toolz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.10.0)
# Requirement already satisfied, skipping upgrade: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.18.1)
# Requirement already satisfied, skipping upgrade: entrypoints in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.3)
# Requirement already satisfied, skipping upgrade: pandas>=0.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.0.5)
# Requirement already satisfied, skipping upgrade: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (2.11.1)
# Requirement already satisfied, skipping upgrade: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (3.2.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2019.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (1.5.0)
# Requirement already satisfied, skipping upgrade: six>=1.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (1.14.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (19.3.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (0.16.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (46.1.3.post20200330)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair) (2.2.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import altair as alt

# Amazon SageMaker 
import sagemaker

# %%
# Initial imports
import requests
import pandas as pd
from path import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Alternatively, use the provided csv file:
file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
crypto_df = pd.read_csv(file_path)
crypto_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df = crypto_df.set_index(crypto_df.columns[0])
crypto_df.head()
# Out:
#              CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# Unnamed: 0
# 42            42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365           365Coin       X11       True   PoW/PoS              NaN
# 404           404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611         SixEleven   SHA-256       True       PoW              NaN
# 808               808   SHA-256       True   PoW/PoS     0.000000e+00
#
#            TotalCoinSupply
# Unnamed: 0
# 42                      42
# 365             2300000000
# 404              532000000
# 611                 611000
# 808                      0

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df.loc[
    crypto_df ["IsTrading"]== True
]

crypto_df.head()
# Out:
#              CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# Unnamed: 0
# 42            42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365           365Coin       X11       True   PoW/PoS              NaN
# 404           404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611         SixEleven   SHA-256       True       PoW              NaN
# 808               808   SHA-256       True   PoW/PoS     0.000000e+00
#
#            TotalCoinSupply
# Unnamed: 0
# 42                      42
# 365             2300000000
# 404              532000000
# 611                 611000
# 808                      0

# %%
# Keep only cryptocurrencies with a working algorithm
#Check for nulls
crypto_df.isnull().sum()

#All cryptocurrencies have a working algorithm
# Out:
# CoinName             0
# Algorithm            0
# IsTrading            0
# ProofType            0
# TotalCoinsMined    459
# TotalCoinSupply      0
# dtype: int64

# %%
# Remove the 'IsTrading' column
crypto_df.drop(columns=['IsTrading'], inplace = True)
crypto_df.head()
# Out:
#              CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# Unnamed: 0
# 42            42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365           365Coin       X11   PoW/PoS              NaN      2300000000
# 404           404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611         SixEleven   SHA-256       PoW              NaN          611000
# 808               808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
# Remove rows with at least 1 null value

# Drop nulls
crypto_df = crypto_df.dropna().copy()
crypto_df.head()

#crypto_df.isnull().sum()
# Out:
#              CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# Unnamed: 0
# 42            42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 404           404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 808               808   SHA-256   PoW/PoS     0.000000e+00               0
# 1337        EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# BTC           Bitcoin   SHA-256       PoW     1.792718e+07        21000000

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df.loc[
    crypto_df ["TotalCoinsMined"] > 0

]

crypto_df.head()
# Out:
#              CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# Unnamed: 0
# 42            42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 404           404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337        EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# BTC           Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH          Ethereum    Ethash       PoW     1.076842e+08               0

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[
    crypto_df.iloc [ : , :] != "N/A"
]

crypto_df.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#              CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# Unnamed: 0
# 42            42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 404           404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337        EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# BTC           Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH          Ethereum    Ethash       PoW     1.076842e+08               0

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df 
coins_name_df = crypto_df[["CoinName"]]
coins_name_df.head()
# Out:
#              CoinName
# Unnamed: 0
# 42            42 Coin
# 404           404Coin
# 1337        EliteCoin
# BTC           Bitcoin
# ETH          Ethereum

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns=['CoinName'])
crypto_df.head()
# Out:
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# Unnamed: 0
# 42            Scrypt   PoW/PoS     4.199995e+01              42
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337             X13   PoW/PoS     2.927942e+10    314159265359
# BTC          SHA-256       PoW     1.792718e+07        21000000
# ETH           Ethash       PoW     1.076842e+08               0

# %%
# Create dummy variables for text features
crypto_df_encoded = pd.get_dummies(crypto_df, columns=["Algorithm", "ProofType"])
crypto_df_encoded_copy =crypto_df_encoded.copy()


crypto_df_encoded.head()
# Out:
#             TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# Unnamed: 0
# 42             4.199995e+01              42                                 0
# 404            1.055185e+09       532000000                                 0
# 1337           2.927942e+10    314159265359                                 0
# BTC            1.792718e+07        21000000                                 0
# ETH            1.076842e+08               0                                 0
#
#             Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  \
# Unnamed: 0
# 42                      0                  0                   0
# 404                     0                  0                   0
# 1337                    0                  0                   0
# BTC                     0                  0                   0
# ETH                     0                  0                   0
#
#             Algorithm_Blake  Algorithm_Blake2S  Algorithm_Blake2b  \
# Unnamed: 0
# 42                        0                  0                  0
# 404                       0                  0                  0
# 1337                      0                  0                  0
# BTC                       0                  0                  0
# ETH                       0                  0                  0
#
#             Algorithm_C11  ...  ProofType_PoW/PoS  ProofType_PoW/PoS   \
# Unnamed: 0                 ...
# 42                      0  ...                  1                   0
# 404                     0  ...                  1                   0
# 1337                    0  ...                  1                   0
# BTC                     0  ...                  0                   0
# ETH                     0  ...                  0                   0
#
#             ProofType_PoW/PoW  ProofType_PoW/nPoS  ProofType_Pos  \
# Unnamed: 0
# 42                          0                   0              0
# 404                         0                   0              0
# 1337                        0                   0              0
# BTC                         0                   0              0
# ETH                         0                   0              0
#
#             ProofType_Proof of Authority  ProofType_Proof of Trust  \
# Unnamed: 0
# 42                                     0                         0
# 404                                    0                         0
# 1337                                   0                         0
# BTC                                    0                         0
# ETH                                    0                         0
#
#             ProofType_TPoS  ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# Unnamed: 0
# 42                       0                               0                   0
# 404                      0                               0                   0
# 1337                     0                               0                   0
# BTC                      0                               0                   0
# ETH                      0                               0                   0
#
# [5 rows x 98 columns]

# %%
# Standardize data
crypto_scaled = StandardScaler().fit_transform(crypto_df_encoded_copy)
print(crypto_scaled)
# Out:
# [[-0.11710817 -0.1528703  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.09396955 -0.145009   -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [ 0.52494561  4.48942416 -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  ...
#  [-0.09561336 -0.13217937 -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.11694817 -0.15255998 -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.11710536 -0.15285552 -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]]

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components

# Initialize PCA model
pca = PCA(n_components=3)


# Get 3 principal components for the  data.
pcs = pca.fit_transform(crypto_scaled )

# %%
# Create a DataFrame with the principal components data
pca_columns = ["PC 1", "PC 2" ,"PC 3"]
pcs_df= pd.DataFrame(
    data=pcs,
    columns=pca_columns,
    index=crypto_df_encoded.index
)

pcs_df.head(10)
# Out:
#                 PC 1      PC 2      PC 3
# Unnamed: 0
# 42         -0.335172  1.042956 -0.494827
# 404        -0.318525  1.043025 -0.495168
# 1337        2.319105  1.622003 -0.530247
# BTC        -0.153693 -1.359293  0.188360
# ETH        -0.164267 -2.079738  0.326104
# LTC        -0.165083 -1.095418 -0.024932
# DASH       -0.400754  1.172968 -0.401307
# XMR        -0.164388 -2.238472  0.436820
# ETC        -0.162711 -2.079842  0.326091
# ZEC        -0.115678 -2.038674  0.232144

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Finding the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)



# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

source=df_elbow

alt.Chart(source).mark_line().encode(
    x="k",
    y="inertia"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Running K-Means with `k=4

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
pcs_df["class"] = model.labels_


#concat all 3 dataframes
clustered_df = pd.concat(([crypto_df, pcs_df,coins_name_df]),axis=1)


#Reorder columns
clustered_df = clustered_df[["Algorithm", "ProofType", "TotalCoinsMined",
            "TotalCoinSupply", "PC 1", "PC 2", "PC 3", "CoinName", "class"]]

clustered_df.head(10)
# Out:
#                  Algorithm ProofType  TotalCoinsMined TotalCoinSupply  \
# Unnamed: 0
# 42                  Scrypt   PoW/PoS     4.199995e+01              42
# 404                 Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337                   X13   PoW/PoS     2.927942e+10    314159265359
# BTC                SHA-256       PoW     1.792718e+07        21000000
# ETH                 Ethash       PoW     1.076842e+08               0
# LTC                 Scrypt       PoW     6.303924e+07        84000000
# DASH                   X11   PoW/PoS     9.031294e+06        22000000
# XMR         CryptoNight-V7       PoW     1.720114e+07               0
# ETC                 Ethash       PoW     1.133597e+08       210000000
# ZEC               Equihash       PoW     7.383056e+06        21000000
#
#                 PC 1      PC 2      PC 3          CoinName  class
# Unnamed: 0
# 42         -0.335172  1.042956 -0.494827           42 Coin      0
# 404        -0.318525  1.043025 -0.495168           404Coin      0
# 1337        2.319105  1.622003 -0.530247         EliteCoin      0
# BTC        -0.153693 -1.359293  0.188360           Bitcoin      1
# ETH        -0.164267 -2.079738  0.326104          Ethereum      1
# LTC        -0.165083 -1.095418 -0.024932          Litecoin      1
# DASH       -0.400754  1.172968 -0.401307              Dash      0
# XMR        -0.164388 -2.238472  0.436820            Monero      1
# ETC        -0.162711 -2.079842  0.326091  Ethereum Classic      1
# ZEC        -0.115678 -2.038674  0.232144             ZCash      1

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 2D-Scatter with the PCA data and the clusters
source = clustered_df

alt.Chart(source).mark_circle(size=60).encode(
    x="PC 1:Q",
    y="PC 2:Q",
    color='class:N',
    tooltip=['CoinName', 'Algorithm', 'TotalCoinsMined', 'TotalCoinSupply']
    
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
#Select required columns
clustered_df = clustered_df[["CoinName", "Algorithm", "ProofType", 
                             "TotalCoinSupply", "TotalCoinsMined", "class"]]

pd.set_option("display.max_rows", None,)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth",None)

clustered_df
# Out:
#                                     CoinName               Algorithm  \
# Unnamed: 0
# 42                                   42 Coin                  Scrypt
# 404                                  404Coin                  Scrypt
# 1337                               EliteCoin                     X13
# BTC                                  Bitcoin                 SHA-256
# ETH                                 Ethereum                  Ethash
# LTC                                 Litecoin                  Scrypt
# DASH                                    Dash                     X11
# XMR                                   Monero          CryptoNight-V7
# ETC                         Ethereum Classic                  Ethash
# ZEC                                    ZCash                Equihash
# BTS                                Bitshares                 SHA-512
# DGB                                 DigiByte                Multiple
# BTCD                             BitcoinDark                 SHA-256
# XPY                                  PayCoin                 SHA-256
# PRC                              ProsperCoin                  Scrypt
# KOBO                                KoboCoin                     X15
# SPR                               Spreadcoin                     X11
# ARG                                 Argentum                  Scrypt
# AUR                              Aurora Coin                  Scrypt
# BLU                                 BlueCoin                  Scrypt
# XMY                               MyriadCoin                Multiple
# MOON                                MoonCoin                  Scrypt
# ZET                                 ZetaCoin                 SHA-256
# SXC                                  SexCoin                  Scrypt
# QTL                                  Quatloo                  Scrypt
# ENRG                              EnergyCoin                  Scrypt
# QRK                                QuarkCoin                   Quark
# RIC                                  Riecoin                 Groestl
# DGC                             Digitalcoin                   Scrypt
# BTB                                   BitBar                  Scrypt
# CAT                                  Catcoin                  Scrypt
# CBX                            CryptoBullion                  Scrypt
# CCN                                CannaCoin                  Scrypt
# CRYPT                              CryptCoin                     X11
# CSC                               CasinoCoin                  Scrypt
# DMD                                  Diamond                 Groestl
# XVG                                    Verge                Multiple
# DVC                                  DevCoin                 SHA-256
# EAC                                EarthCoin                  Scrypt
# EFL                                 E-Gulden                  Scrypt
# EMC2                             Einsteinium                  Scrypt
# EMD                                  Emerald                  Scrypt
# EXCL                          Exclusive Coin                     PoS
# FLT                              FlutterCoin                  Scrypt
# FRK                                   Franko                  Scrypt
# FTC                              FeatherCoin               NeoScrypt
# GDC                                GrandCoin                  Scrypt
# GLC                               GlobalCoin                  Scrypt
# GLD                                 GoldCoin                  Scrypt
# HBN                              HoboNickels                  Scrypt
# HYP                               HyperStake                     X11
# IFC                            Infinite Coin                  Scrypt
# IOC                                   IOCoin                     X11
# IXC                                   IXcoin                 SHA-256
# KGC                               KrugerCoin                  Scrypt
# LKY                                LuckyCoin                  Scrypt
# LTB                                 Litebar                   Scrypt
# MAX                                  MaxCoin                    SHA3
# MEC                                 MegaCoin                  Scrypt
# MED                        MediterraneanCoin     HybridScryptHash256
# MINT                                MintCoin                  Scrypt
# MINC                                 MinCoin                  Scrypt
# MZC                                 MazaCoin                 SHA-256
# NAUT                           Nautilus Coin                  Scrypt
# NAV                                  NavCoin                     X13
# NOBL                               NobleCoin                  Scrypt
# NMC                                 Namecoin                 SHA-256
# NYAN                                NyanCoin                  Scrypt
# OPAL                                OpalCoin                     X13
# ORB                                Orbitcoin               NeoScrypt
# POT                                  PotCoin                  Scrypt
# PXC                              PhoenixCoin                  Scrypt
# RDD                                 Reddcoin                  Scrypt
# RPC                              RonPaulCoin                  Scrypt
# SBC                               StableCoin                  Scrypt
# SMC                                SmartCoin                  Scrypt
# SUPER                              SuperCoin                     X11
# SYNC                                SyncCoin                     X11
# SYS                                  SysCoin                 SHA-256
# TES                                TeslaCoin                Multiple
# TGC                                TigerCoin                 SHA-256
# TIT                               TittieCoin                 PHI1612
# TOR                                  TorCoin                     X11
# TRC                                TerraCoin                 SHA-256
# UNB                          UnbreakableCoin                 SHA-256
# UNO                               Unobtanium                 SHA-256
# URO                                  UroCoin                     X11
# USDE                    UnitaryStatus Dollar                  Scrypt
# UTC                                UltraCoin                  Scrypt
# VIA                                  ViaCoin                  Scrypt
# VRC                                 VeriCoin                  Scrypt
# VTC                                 Vertcoin               Lyra2REv2
# WDC                                WorldCoin                  Scrypt
# XC                                  X11 Coin                     X11
# XCR                                   Crypti                Multiple
# XJO                                JouleCoin                 SHA-256
# XST                              StealthCoin                     X13
# ZCC                                 ZCC Coin                  Scrypt
# BCN                                 ByteCoin             CryptoNight
# XDN                             DigitalNote              CryptoNight
# BURST                              BurstCoin               Shabal256
# SJCX                               StorjCoin            Counterparty
# MONA                                MonaCoin                  Scrypt
# NTRN                                 Neutron                 SHA-256
# FAIR                                FairCoin                 Groestl
# NLG                                   Gulden                  Scrypt
# RBY                                 RubyCoin                  Scrypt
# PTC                               PesetaCoin                  Scrypt
# KORE                                    Kore                     X13
# WBB                          Wild Beast Coin                  Scrypt
# NOTE                                  Dnotes                  Scrypt
# FLO                                      Flo                  Scrypt
# 8BIT                               8BIT Coin                  Scrypt
# STV                              Sativa Coin                     X13
# ABY                                  ArtByte                  Scrypt
# FLDC                            Folding Coin        Stanford Folding
# U                                      Ucoin                     X11
# UIS                                   Unitus                Multiple
# CYP                           CypherPunkCoin                   QuBit
# OMC                                 OmniCron                  Scrypt
# VTR                                 Vtorrent                  Scrypt
# GRE                                GreenCoin                  Scrypt
# XCN                               Cryptonite                  M7 POW
# MSC                               MasterCoin                  Scrypt
# SOON                                SoonCoin                 SHA-256
# 1CR                                  1Credit                  Scrypt
# ISL                                 IslaCoin                     X11
# NXS                                    Nexus                    SHA3
# MARS                               MarsCoin                      X11
# CTO                                   Crypto                 Lyra2RE
# ACP                         Anarchists Prime                 SHA-256
# DRZ                                   Droidz                   QUAIT
# BSC                                 BowsCoin                     X11
# SQL                              Squall Coin                     X11
# SONG                               Song Coin                  Scrypt
# ZNY                                  BitZeny                  Scrypt
# DIGS                                 Diggits                  Scrypt
# EXP                                  Expanse                  Ethash
# CON                                   Paycon                     X13
# SC                                   Siacoin                 Blake2b
# EMC                                 Emercoin                 SHA-256
# EGC                            EverGreenCoin                     X15
# MND                                 MindCoin                     X11
# I0C                                   I0coin                 SHA-256
# DCR                                   Decred                BLAKE256
# RVR                            Revolution VR                  Scrypt
# HODL                                HOdlcoin  1GB AES Pattern Search
# EDRC                                 EDRCoin                 SHA-256
# HTC                                  Hitcoin                     X11
# GAME                             Gamecredits                  Scrypt
# DBIC                               DubaiCoin                 SHA-256
# DIEM                           CarpeDiemCoin                 SHA-256
# PWR                                 PWR Coin                   NIST5
# BLRY                             BillaryCoin                  Scrypt
# GPU                                 GPU Coin                  Scrypt
# ADZ                                  Adzcoin                     X11
# SOIL                                SoilCoin                  Dagger
# YOC                                   YoCoin                  Scrypt
# SIB                                  SibCoin                 X11GOST
# ERC                               EuropeCoin                     X11
# ZEIT                                ZeitCoin                  Scrypt
# SWING                              SwingCoin                 SHA-256
# SAFEX                       SafeExchangeCoin                  Scrypt
# NEBU                          Nebuchadnezzar                     PoS
# FRN                                   Francs                  Scrypt
# BOLI                             BolivarCoin                     X11
# XRA                                 Ratecoin                     X11
# REV                                   Revenu                 SHA-256
# CKC                                Clockcoin                 SHA-256
# VIP                               VIP Tokens                   NIST5
# BSD                                  BitSend                     X11
# OMNI                                    Omni                  Scrypt
# LIR                              Let it Ride                 POS 3.0
# PUT                                PutinCoin                  Scrypt
# IBANK                              iBankCoin                  Scrypt
# FRWC                          Frankywillcoin                  Scrypt
# MUDRA                              MudraCoin                     X13
# PIZZA                              PizzaCoin                     X11
# LC                             Lutetium Coin                     X11
# KMD                                   Komodo                Equihash
# GB                                GoldBlocks                     X11
# CTC                               CarterCoin                  Scrypt
# KRB                                    Karbo             CryptoNight
# BXT                                BitTokens                 SHA-256
# ZYD                                ZayedCoin                 SHA-256
# MST                              MustangCoin                     X11
# ZNE                                 ZoneCoin                  Scrypt
# COVAL                      Circuits of Value                Multiple
# ROOT                                RootCoin                  Scrypt
# DOPE                                DopeCoin                  Scrypt
# BTCR                             BitCurrency                  Scrypt
# DLC                               DollarCoin                 SHA-256
# SCN                                 Swiscoin                  Scrypt
# SH                                  Shilling                  Scrypt
# BUZZ                                BuzzCoin                SHA-256D
# XPO                                    Opair                     PoS
# PSB                                  PesoBit                  Scrypt
# HALLO                         Halloween Coin                     X11
# XZC                                    ZCoin                  Lyra2Z
# CFC                               CoffeeCoin                     PoS
# ROYAL                              RoyalCoin                     X13
# GNJ                             GanjaCoin V2                     X14
# TEAM                                  TeamUP                     PoS
# LANA                                LanaCoin                SHA-256D
# ELE                               Elementrem                  Ethash
# ZCL                                 ZClassic                Equihash
# ARK                                      ARK                    DPoS
# INSANE                            InsaneCoin                     X11
# KLC                                 KiloCoin                  Scrypt
# ATX                                ArtexCoin                     X11
# EMB                                EmberCoin                     X13
# XEN                                XenixCoin                     X11
# FRE                                 FreeCoin                     PoS
# PLNC                                 PLNCoin                  Scrypt
# ARCO                            AquariusCoin                  Scrypt
# KURT                                 Kurrent                     X11
# XCRE                                 Creatio                     PoS
# ENT                                 Eternity                     X11
# EUC                                 Eurocoin                 SHA-256
# BCF                              BitcoinFast                  Scrypt
# XSN                                 Stakenet                     X11
# BCCOIN                       BitConnect Coin                  Scrypt
# MONEY                              MoneyCoin                  Scrypt
# XNG                                   Enigma                     X11
# XCI                   Cannabis Industry Coin             CryptoNight
# RC                                Russiacoin                  Scrypt
# PND                                PandaCoin                  Scrypt
# UNITS                              GameUnits                  Scrypt
# GAKH                                GAKHcoin                  Scrypt
# ASAFE2                               Allsafe                   Quark
# LTCR                               LiteCreed                   QuBit
# OS76                              OsmiumCoin                  Scrypt
# BIC                               Bikercoins             CryptoNight
# HXX                                 HexxCoin                 Lyra2RE
# KED                    Klingon Empire Darsek                  Scrypt
# IOP                       Internet of People                 SHA-256
# KUSH                                KushCoin                     X11
# PRX                               Printerium                  Scrypt
# PAC                                  PacCoin                     X11
# IMPCH                                Impeach                  Scrypt
# CTL                                  Citadel          CryptoNight-V7
# ZBC                               Zilbercoin                  Scrypt
# FRST                               FirstCoin                  Scrypt
# BVC                               BeaverCoin                  Scrypt
# FIND                                FindCoin                     X13
# VLTC                               VaultCoin                     X11
# ZER                                     Zero                Equihash
# CHAT                                OpenChat                  Scrypt
# CDN                             Canada eCoin                  Scrypt
# ZOI                                     Zoin                 Lyra2RE
# RNS                                RenosCoin                  Scrypt
# DBIX                               DubaiCoin        Dagger-Hashimoto
# XVP                            VirtacoinPlus                     X11
# TAJ                                  TajCoin                 Blake2S
# IMX                                   Impact                     X11
# EB3                                  EB3coin                  Scrypt
# ATMOS                                  Atmos                     PoS
# HPC                                HappyCoin                     X11
# CXT                                 Coinonat                   NIST5
# MCRN                              MacronCoin                     PoS
# RAIN                              Condensate                     X11
# IMS                 Independent Money System                  Scrypt
# ARGUS                              ArgusCoin                  Scrypt
# LMC                                 LomoCoin                  Scrypt
# PROC                             ProCurrency                 SHA-256
# XGR                              GoldReserve                     X11
# BENJI                             BenjiRolls                  Scrypt
# GRW                               GrowthCoin                  Scrypt
# ILC                                   ILCoin                 SHA-256
# PHR                                   Phreak                     PoS
# DEA                               Degas Coin                  Scrypt
# HTML5                             HTML5 Coin                     X15
# USC                     Ultimate Secure Cash                 SHA-256
# EQT                               EquiTrader                  Scrypt
# QTUM                                    QTUM                 POS 3.0
# QRL                 Quantum Resistant Ledger          CryptoNight-V7
# ESP                                   Espers                     536
# DYN                                  Dynamic                 Argon2d
# NANO                                    Nano                 Blake2b
# CHAN                                ChanCoin              Cloverhash
# DCY                              Dinastycoin             CryptoNight
# DNR                                 Denarius                   NIST5
# DP                              DigitalPrice                     X11
# VUC                        Virta Unique Coin                   NIST5
# BTPL                          Bitcoin Planet                   Skein
# UNIFY                                  Unify                  Scrypt
# BRIT                                BritCoin                     X13
# SOCC                              SocialCoin                  Scrypt
# ARC                               ArcticCoin                     X11
# DAS                                      DAS                     X11
# LINDA                                  Linda                  Scrypt
# XLC                               LeviarCoin             CryptoNight
# ONION                              DeepOnion                     X13
# BTX                                  Bitcore             Time Travel
# GCN                                 gCn Coin                  Scrypt
# SMART                              SmartCash                  Keccak
# SIGT                                Signatum     SkunkHash v2 Raptor
# ONX                                     Onix                     X11
# CRM                                    Cream                   Skein
# BCH                             Bitcoin Cash                 SHA-256
# XMCC                                 Monoeci                     X11
# DFT                                Draftcoin                  Scrypt
# VET                                  Vechain   VeChainThor Authority
# SOJ                             Sojourn Coin                  Scrypt
# STCN                               Stakecoin                     PoS
# NYC                              NewYorkCoin                  Scrypt
# FRAZ                                FrazCoin                  Scrypt
# KRONE                              Kronecoin                  Scrypt
# ACC                                   AdCoin                  Scrypt
# LINX                                    Linx                  Scrypt
# XCXT                               CoinonatX                  Scrypt
# ETHD                           Ethereum Dark                  Scrypt
# SUMO                                Sumokoin             CryptoNight
# ODN                                 Obsidian                 SHA-512
# ADA                                  Cardano               Ouroboros
# REC                                Regalcoin                     X11
# BTCZ                                BitcoinZ                Equihash
# TZC                               TrezarCoin               NeoScrypt
# ELM                                 Elements                     X11
# TER                            TerraNovaCoin                  Scrypt
# VIVO                               VIVO Coin               NeoScrypt
# RUP                                    Rupee               Lyra2REv2
# BTG                             Bitcoin Gold                Equihash
# WOMEN                              WomenCoin                  Scrypt
# MAY                         Theresa May Coin                 SHA-256
# NAMO                                NamoCoin                   NIST5
# LUX                                  LUXCoin                 PHI1612
# PIRL                                    Pirl                  Dagger
# XIOS                                    Xios                  Scrypt
# BTDX                            Bitcloud 2.0                   Quark
# EBST                                  eBoost                  Scrypt
# KEK                                  KekCoin                 POS 2.0
# BLHC                           BlackholeCoin                  Scrypt
# XIN                       Infinity Economics                 SHA-256
# PURA                                    Pura                     X11
# INN                                   Innova               NeoScrypt
# ELLA                                 Ellaism                  Ethash
# GBX                                   GoByte               NeoScrypt
# MAG                                   Magnet                     X11
# TAU                               Lamden Tau                    DPoS
# ECA                                  Electra                   NIST5
# BCD                          Bitcoin Diamond                     X13
# XSH                                   SHIELD                Multiple
# CNBC                        Cash & Back Coin                  Scrypt
# XUN                                UltraNote             CryptoNight
# COAL                                 BitCoal             CryptoNight
# DAXX                                DaxxCoin                  Ethash
# BWK                                  Bulwark                   NIST5
# KLKS                                Kalkulus                   Quark
# AC3                                      AC3                     X11
# LTHN                                 Lethean          CryptoNight-V7
# GER                               GermanCoin                  Scrypt
# LTCU                          LiteCoin Ultra                  Scrypt
# POP                              PopularCoin                  Scrypt
# PNX                                 PhantomX                     X11
# PHO                                   Photon                BLAKE256
# SUCR                                   Sucre                     X11
# SPK                                SparksPay               NeoScrypt
# WAGE                                Digiwage                   Quark
# GUN                                  GunCoin               NeoScrypt
# IRL                                IrishCoin                  Scrypt
# TROLL                              Trollcoin                  Scrypt
# LCP                            Litecoin Plus                  Scrypt
# MONK                          Monkey Project                     X11
# PCOIN                           Pioneer Coin                     X11
# UBTC                           UnitedBitcoin                 SHA-256
# ITZ                                Interzone                     C11
# TPAY                                TokenPay                 POS 3.0
# MCT         1717 Masonic Commemorative Token                  Ethash
# MBC                              My Big Coin                  Scrypt
# TRTL                              TurtleCoin             CryptoNight
# MUN                                  MUNcoin               SkunkHash
# USX                    Unified Society USDEX                  Scrypt
# NBR                              Niobio Cash             CryptoNight
# SSS                               ShareChain                  Scrypt
# TRF                               Travelflex                  Dagger
# KREDS                                  KREDS               Lyra2REv2
# TOKC                              Tokyo Coin                     X13
# BBP                                 BiblePay      Proof-of-BibleHash
# LCC                             LitecoinCash          SHA-256 + Hive
# FLIP                                 BitFlip                  Scrypt
# LOT                                LottoCoin                  Scrypt
# CIF                  Crypto Improvement Fund                     X11
# SPD                                  Stipend                     C11
# POA                              Poa Network      Proof-of-Authority
# PUSHI                                  Pushi                     X11
# ELP                                 Ellerium                   XEVAN
# VLX                                    Velox                  Scrypt
# ONT                                 Ontology                    VBFT
# CLO                         Callisto Network                  Ethash
# TUBE                                 BitTube             CryptoNight
# PSD                                 Poseidon                  Scrypt
# ADK                             Aidos Kuneen                   IMesh
# BSX                                 Bitspace                   NIST5
# BRIA                                Briacoin                  Scrypt
# IC                                  Ignition                  Scrypt
# BTL                                Bitrolium                Equihash
# MEDIC                              MedicCoin                  Scrypt
# ALPS                         Alpenschillling                  Lyra2Z
# BITG                           Bitcoin Green          Green Protocol
# DEV                             Deviant Coin                     PoS
# ABJ                                  Abjcoin                  Scrypt
# SEM                                    Semux     Semux BFT consensus
# FTO                               FuturoCoin                     X11
# CARE                                 Carebit                   Quark
# NZL                                  Zealium                     PoS
# XMC                           Monero Classic             CryptoNight
# PROTON                                Proton                    X16R
# DEAL                               iDealCash                  Scrypt
# JUMP                                Jumpcoin                   NIST5
# INFX                                 Infinex                 Lyra2RE
# XBI                        Bitcoin Incognito                   XEVAN
# KEC                                    KEYCO                  Tribus
# HWC                            HollyWoodCoin                  Scrypt
# GIN                                  GINcoin                  Lyra2Z
# PLTC                              PlatinCoin             CryptoNight
# LOKI                                    Loki       CryptoNight Heavy
# NCP                              Newton Coin             CryptoNight
# SIC                                Swisscoin                  Scrypt
# XT3                                    Xt3ch                  Scrypt
# MGD                                 MassGrid    Jump Consistent Hash
# VIG                                   TheVig                SHA-256D
# PLURA                              PluraCoin             CryptoNight
# EMAR                              EmaratCoin                  Scrypt
# DKD                                   Dekado                     X15
# LYNX                                    Lynx                  Scrypt
# POSQ                          Poseidon Quark                   Quark
# BWS                         BitcoinWSpectrum                 SHA-256
# MUSE                                    Muse                    DPoS
# XMN                                   Motion                    X16R
# PLUS1                            PlusOneCoin                 HMQ1725
# AXE                                      Axe                     X11
# TRVC                              Trivechain                    X16R
# DTEM                                  Dystem                   Quark
# GIC                                    Giant                   Quark
# PNY                               Peony Coin                  Scrypt
# ABS                            Absolute Coin               Lyra2REv2
# VITAE                                  Vitae                   Quark
# HEX                                  HexCoin                  Scrypt
# TPC                                   TPCash                  Scrypt
# WEBC                                Webchain          CryptoNight-V7
# RYO                                      Ryo         Cryptonight-GPU
# URALS                             Urals Coin                   XEVAN
# QWC                               Qwertycoin       CryptoNight Heavy
# ARE                                   ARENON                     X11
# EUNO                                    EUNO                     X11
# MMO                                  MMOCoin                  Scrypt
# KETAN                                  Ketan                     PoS
# PPAI                             Project Pai                 SHA-256
# XDNA                                    XDNA                  Keccak
# PAXEX                                  PAXEX                     X11
# AZART                                  Azart                     X11
# TSC                             ThunderStake                  Scrypt
# KCASH                                  Kcash                 SHA-512
# XCG                                  Xchange                    X16R
# AAC                        Acute Angle Cloud               ECC 256K1
# CRYP                             CrypticCoin                Equihash
# BTXC                             Bettex coin                   XEVAN
# ACM                                 Actinium                  Lyra2Z
# BSV                               Bitcoin SV                 SHA-256
# BITM                                BitMoney                   XEVAN
# JMC                    Junson Ming Chan Coin                     X11
# FRED                              FREDEnergy             CryptoNight
# HERB                                HerbCoin                   Quark
# UMO                       Universal Molecule                   Blake
# LIT                                  Lithium                   Blake
# PIRATE                            PirateCash                Equihash
# EXO                                   Exosis                  Exosis
# BLTG                             Block-Logic                  Scrypt
# OWC                                    Oduwa                  Scrypt
# BEAM                                    Beam                Equihash
# GALI                                 Galilel                   Quark
# BTH                                Bithereum                Equihash
# CSPN                           Crypto Sports                   Quark
# CREDIT                                Credit                  Scrypt
# SLC                                    SLICE                   QuBit
# DASHP                          Dash Platinum                     X11
# NSD                                Nasdacoin                  Scrypt
# BEET                             Beetle Coin                   XEVAN
# TTN                               Titan Coin                SHA-256D
# AWR                                    Award                     X11
# BLAST                                  BLAST                 SHA-256
# XRC                          Bitcoin Rhodium                     X13
# GLT                              GlobalToken                 SHA-256
# INSN                             Insane Coin                     X11
# ALX                                     ALAX                    DPoS
# LDOGE                               LiteDoge                  Scrypt
# SLR                                SolarCoin                  Scrypt
# TRK                                TruckCoin                     X11
# UFO                                 UFO Coin               NeoScrypt
# OC                                OrangeCoin                  Scrypt
# BLC                                BlakeCoin                   Blake
# BITS                             BitstarCoin                  Scrypt
# NEOS                                NeosCoin                 SHA-256
# HYPER                              HyperCoin                  Scrypt
# PINK                                PinkCoin                     X11
# CESC                           Crypto Escudo                  Scrypt
# ADC                                AudioCoin                  Scrypt
# NKA                                 IncaKoin                 SHA-256
# PIGGY                             Piggy Coin                     X11
# CRW                               Crown Coin                 SHA-256
# GEN                                 Genstake                  Scrypt
# SMLY                              SmileyCoin                  Scrypt
# MI                                XiaoMiCoin                  Scrypt
# GRS                              Groestlcoin                 Groestl
# CPC                                CapriCoin                     X11
# CLUB                                ClubCoin                  Scrypt
# RADS                                  Radium                     PoS
# BTA                                     Bata                  Scrypt
# PAK                                  Pakcoin                  Scrypt
# CRB                               Creditbit                      X11
# OK                                    OKCash                 SHA-256
# LSK                                     Lisk                    DPoS
# XHI                                   HiCoin                  Scrypt
# XWC                                WhiteCoin                  Scrypt
# FSC                           FriendshipCoin               NeoScrypt
# J                                   JoinCoin                Multiple
# TRI                           Triangles Coin                     X13
# VOLLAR                                Vollar         Equihash+Scrypt
# EOS                                      EOS                    DPoS
# RCC                            Reality Clash                  Ethash
# OXY                                  Oxycoin                    DPoS
# TCH                                TigerCash                 SHA-256
# WAVES                                  Waves              Leased POS
# PART                                 Particl                     PoS
# BTT                               BitTorrent                   TRC10
# NXT                                      Nxt                     PoS
# ZEPH                                  ZEPHYR                 SHA-256
# GAP                                  Gapcoin                  Scrypt
# BDX                                   Beldex             CryptoNight
# ZEN                                  Horizen                Equihash
# XBC                              BitcoinPlus                  Scrypt
#
#                        ProofType    TotalCoinSupply  TotalCoinsMined  class
# Unnamed: 0
# 42                       PoW/PoS                 42     4.199995e+01      0
# 404                      PoW/PoS          532000000     1.055185e+09      0
# 1337                     PoW/PoS       314159265359     2.927942e+10      0
# BTC                          PoW           21000000     1.792718e+07      1
# ETH                          PoW                  0     1.076842e+08      1
# LTC                          PoW           84000000     6.303924e+07      1
# DASH                     PoW/PoS           22000000     9.031294e+06      0
# XMR                          PoW                  0     1.720114e+07      1
# ETC                          PoW          210000000     1.133597e+08      1
# ZEC                          PoW           21000000     7.383056e+06      1
# BTS                          PoS         3600570502     2.741570e+09      0
# DGB                          PoW        21000000000     1.140622e+10      1
# BTCD                     PoW/PoS           22000000     1.288862e+06      0
# XPY                          PoS           12500000     1.199533e+07      0
# PRC                          PoW           21000000     5.768310e+06      1
# KOBO                     PoW/PoS          350000000     2.554254e+07      0
# SPR                          PoW           20000000     1.114973e+07      1
# ARG                          PoW           64000000     1.220580e+07      1
# AUR                      PoW/PoS           16768584     1.813510e+07      0
# BLU                      PoW/PoS                  0     6.354239e+08      0
# XMY                          PoW         2000000000     1.688254e+09      1
# MOON                         PoW       384000000000     8.800000e+01      1
# ZET                          PoW          169795588     1.702044e+08      1
# SXC                          PoW          250000000     1.289410e+08      1
# QTL                          PoW          100000000     7.357795e+06      1
# ENRG                     PoW/PoS                  0     1.230628e+08      0
# QRK                          PoW          247000000     2.595572e+08      1
# RIC                          PoW           84000000     4.954859e+07      1
# DGC                          PoW           48166000     3.344299e+07      1
# BTB                      PoW/PoS             500000     4.257948e+04      0
# CAT                          PoW          21000000      7.219957e+06      1
# CBX                      PoW/PoS            1000000     1.039117e+06      0
# CCN                          PoW           13140000     4.703880e+06      1
# CRYPT                        PoW           18000000     4.996986e+06      1
# CSC                          PoC        40000000000     4.000000e+10      0
# DMD                      PoW/PoS            4380000     3.304488e+06      0
# XVG                          PoW        16555000000     1.592953e+10      1
# DVC                          PoW        21000000000     1.877386e+10      1
# EAC                          PoW        13500000000     1.253902e+10      1
# EFL                          PoW          21000000      2.091048e+07      1
# EMC2                         PoW          299792458     2.188719e+08      1
# EMD                          PoW           32000000     1.949679e+07      1
# EXCL                         PoS                  0     5.679705e+06      0
# FLT                  PoS/PoW/PoT                  0     4.618299e+08      0
# FRK                          PoW           11235813     1.142732e+06      1
# FTC                          PoW          336000000     2.086691e+08      1
# GDC                          PoW         1420609614     8.841258e+08      1
# GLC                          PoW           70000000     6.567272e+07      1
# GLD                          PoW           72245700     4.165865e+07      1
# HBN                      PoW/PoS          120000000     8.926693e+07      0
# HYP                          PoS                  0     1.678520e+09      0
# IFC                          PoW        90600000000     9.059575e+10      1
# IOC                      PoW/PoS           22000000     1.765091e+07      0
# IXC                          PoW           21000000     2.108935e+07      1
# KGC                          PoW          265420800     1.514476e+08      1
# LKY                          PoW           20000000     1.932632e+07      1
# LTB                          PoW            1350000     1.104344e+06      1
# MAX                      PoW/PoS          100000000     6.144580e+07      0
# MEC                          PoW           42000000     3.815200e+07      1
# MED                          PoW          200000000     4.043186e+07      1
# MINT                         PoS                  0     2.129393e+10      0
# MINC                         PoW           10000000     5.804205e+06      1
# MZC                      PoW/PoS         2419200000     1.613836e+09      0
# NAUT                         PoS           16180000     1.618000e+07      0
# NAV                      PoW/PoS                  0     6.608710e+07      0
# NOBL                         PoW        15000000000     2.366066e+09      1
# NMC                          PoW           21000000     1.473640e+07      1
# NYAN                         PoW          337000000     3.347092e+08      1
# OPAL                     PoW/PoS                  0     1.515636e+07      0
# ORB                      PoW/PoS            3770000     3.220616e+06      0
# POT                      PoW/PoS          420000000     2.226772e+08      0
# PXC                      PoW/PoS           98000000     7.395927e+07      0
# RDD                      PoW/PoS                  0     2.931557e+10      0
# RPC                          PoW           21000000     1.104157e+06      1
# SBC                          PoW          250000000     2.421518e+07      1
# SMC                          PoW           51200000     2.559374e+07      1
# SUPER                        PoS                  0     5.070766e+07      0
# SYNC                     PoW/PoS               1000     1.177000e+03      0
# SYS                          PoW          888000000     5.633365e+08      1
# TES                          PoS          100000000     8.026046e+07      0
# TGC                          PoW           47011968     4.353680e+07      1
# TIT                          PoS         2300000000     1.622326e+09      0
# TOR                      PoW/PoS           10000000     1.431851e+06      0
# TRC                          PoW           42000000     2.293540e+07      1
# UNB                          PoW           80000000     2.278150e+06      1
# UNO                          PoW             250000     2.009118e+05      1
# URO                          PoW                  0     1.207310e+06      1
# USDE                     PoW/PoS         1600000000     1.098953e+09      0
# UTC                      PoW/PoS          100000000     5.023521e+07      0
# VIA                          PoW           23000000     2.315089e+07      1
# VRC                         PoST                  0     3.202111e+07      0
# VTC                          PoW           84000000     5.117372e+07      1
# WDC                          PoW          265420800     1.196069e+08      1
# XC                       PoW/PoS            5500000     6.950831e+06      0
# XCR                          PoS                  0     1.000000e+08      0
# XJO                          PoW           45000000     3.919574e+07      1
# XST                      PoW/PoS                  0     3.309373e+07      0
# ZCC                      PoW/PoS         1000000000     1.479902e+08      0
# BCN                          PoW       184467440735     1.840668e+11      1
# XDN                          PoW        10000000000     6.906588e+09      1
# BURST                        PoC         2158812800     1.813034e+09      0
# SJCX                         PoS          500000000     5.117314e+07      0
# MONA                         PoW          105120000     6.819467e+07      1
# NTRN                     PoW/PoS           68000000     3.912169e+07      0
# FAIR                     PoW/PoS                  0     5.319383e+07      0
# NLG                          PoW         1680000000     4.150324e+08      1
# RBY                          PoS                  0     2.718449e+07      0
# PTC                          PoW          166386000     1.375177e+08      1
# KORE                     PoW/PoS           12000000     2.022465e+06      0
# WBB                          PoW            2628000     1.819192e+05      1
# NOTE                         PoS          500000000     1.746461e+08      0
# FLO                          PoW          160000000     1.522707e+08      1
# 8BIT                     PoW/PoS                  0     1.467841e+06      0
# STV                      PoW/PoS           10000000     7.096834e+06      0
# ABY                          PoW         1000000000     7.925372e+08      1
# FLDC                         PoW         1000000000     7.194170e+08      1
# U                            PoS           20000000     2.689812e+06      0
# UIS                          PoW                  0     6.511330e+07      1
# CYP                          PoW                  0     6.365285e+06      1
# OMC                          PoW            3371337     1.014004e+07      1
# ...
# PIRL                         PoW       156306732.71     3.398698e+07      1
# XIOS                     PoW/PoS           21000000     2.149688e+06      0
# BTDX                     PoW/PoS          200000000     3.071155e+07      0
# EBST                         PoW          100000000     9.999000e+07      1
# KEK                          PoS           21000000     1.233081e+07      0
# BLHC                     PoW/PoS       14788275.991     1.636254e+07      0
# XIN                          PoS         9000000000     9.000000e+09      0
# PURA                         PoW          350000000     1.752159e+08      1
# INN                          PoW           45000000     6.375259e+06      1
# ELLA                         PoW          280000000     1.275637e+07      1
# GBX                          PoW           31800000     5.832307e+06      1
# MAG                      PoW/PoS          144000000     3.819859e+07      0
# TAU                         DPoS          500000000     2.880906e+08      0
# ECA                      PoW/PoS        30000000000     2.839915e+10      0
# BCD                      PoW/PoS          210000000     1.835340e+08      0
# XSH                          PoW          660000000     4.817306e+08      1
# CNBC                     PoW/PoS          210000000     1.109770e+08      0
# XUN                          PoW        85000000000     1.928182e+10      1
# COAL                         PoW           12500000     4.500000e+06      1
# DAXX                         PoW        10000000000     5.208918e+08      1
# BWK                          PoS           27716121     1.324718e+07      0
# KLKS                         PoS           20000000     1.695576e+07      0
# AC3                          PoW          550000000     8.031621e+07      1
# LTHN                         PoW          999481516     4.412502e+08      1
# GER                      PoW/PoS        50000000000     4.911500e+09      0
# LTCU                     PoW/PoS          150000000     8.419402e+06      0
# POP                          PoW         4999999999     3.964201e+09      1
# PNX                      PoW/PoS           50000000     4.517421e+07      0
# PHO                          PoW        90000000000     3.008967e+10      1
# SUCR                         PoW           19800000     4.229041e+06      1
# SPK                          PoW           21000000     7.847417e+06      1
# WAGE                         PoS          120000000     2.729968e+07      0
# GUN                          PoW          500000000     2.997980e+08      1
# IRL                          PoW           64000000     4.548305e+07      1
# TROLL                    PoW/PoS          900000000     5.910227e+08      0
# LCP                      PoW/PoS            4000000     2.504486e+06      0
# MONK                         PoS           21000000     4.407252e+06      0
# PCOIN                        PoW           23000000     8.478104e+06      1
# UBTC                         PoW           20166000     2.016600e+07      1
# ITZ                          PoW           23000000     1.191659e+07      1
# TPAY                         PoS           25000000     2.044586e+07      0
# MCT                          PoS            1618033     1.618033e+06      0
# MBC                  PoW and PoS           30000000     9.399343e+06      0
# TRTL                         PoW      1000000000000     5.313984e+10      1
# MUN                          PoW           16600000     4.818339e+06      1
# USX                      PoW/PoS          232000000     2.348463e+08      0
# NBR                          PoW          336000000     1.339325e+08      1
# SSS                          PoW        10000000000     1.000000e+10      1
# TRF                          PoW          100000000     1.073253e+08      1
# KREDS                        PoW         1100000000     6.437959e+08      1
# TOKC                         PoS          800000000     2.302989e+08      0
# BBP                         POBh         5200000000     1.772092e+09      3
# LCC                   PoW + Hive          840000000     6.383823e+08      3
# FLIP                         PoW           40000000     1.244610e+07      1
# LOT                          PoW        18406979840     1.449101e+10      1
# CIF                          PoW          500000000     2.112976e+08      1
# SPD                      PoW/PoS           19340594     1.125134e+07      0
# POA                          PoA          252460800     2.044790e+08      3
# PUSHI                    PoW/PoS           25000000     2.167827e+06      0
# ELP                      PoW/PoS           60000000     4.192754e+05      0
# VLX                          PoS          124000000     2.557001e+07      0
# ONT                          PoS         1000000000     6.508486e+08      0
# CLO                          PoW         6500000000     2.476125e+08      1
# TUBE                         PoW         1000000000     8.004908e+07      1
# PSD                          PoW           21000000     4.070212e+06      1
# ADK                          PoW           25000000     2.500000e+07      1
# BSX                      PoW/PoS           50000000     1.378785e+07      0
# BRIA                     PoW/PoS            3000000     8.456378e+05      0
# IC                       PoW/PoS            5000000     1.182154e+06      0
# BTL                          PoW           70000000     7.135548e+07      1
# MEDIC                        PoS          500000000     2.672977e+08      0
# ALPS                         PoW          300000000     2.734050e+07      1
# BITG                         PoS           21000000     9.803691e+06      0
# DEV                          PoS           88000000     2.187659e+07      0
# ABJ                      PoW/PoS           30000000     9.880502e+06      0
# SEM                         DPoS          100000000     1.231147e+06      0
# FTO                          PoW          100000000     3.180146e+07      1
# CARE                     PoW/PoS          200000000     1.397396e+08      0
# NZL                          PoS           80000000     1.107525e+07      0
# XMC                          PoW           18400000     1.601686e+07      1
# PROTON                       PoS           45000000     4.403800e+06      0
# DEAL                     PoW/PoS         5121951220     1.404158e+09      0
# JUMP                         PoW           21000000     2.106935e+07      1
# INFX                         PoW           26280000     5.097690e+06      1
# XBI                      PoS/PoW           21000000     1.090496e+07      0
# KEC                          PoW           18000000     7.954470e+05      1
# HWC                          PoS           26000000     3.870681e+07      0
# GIN                          PoW           10500000     6.986400e+06      1
# PLTC                         PoW          600000518     8.430000e+04      1
# LOKI                         PoW          150000000     1.915363e+07      1
# NCP                          PoW       184000000000     4.129452e+10      1
# SIC                      PoW/PoS        10200000000     1.020000e+10      0
# XT3                          PoS           44000000     7.630000e+06      0
# MGD                          PoW          168000000     1.358624e+08      1
# VIG                      PoW/PoS          100000000     3.323818e+07      0
# PLURA                        PoW         1000000000     5.600860e+08      1
# EMAR                     PoW/PoS           84000000     2.159934e+07      0
# DKD                          PoS           90000000     3.028420e+07      0
# LYNX                        HPoW        92000000000     7.787206e+10      0
# POSQ                         PoS         650000000      2.716265e+06      0
# BWS                          PoS          100262205     5.781100e+07      0
# MUSE                         PoS          18081806      1.819494e+07      0
# XMN                          PoW           22075700     8.125865e+06      1
# PLUS1                        PoW           21000000     8.645406e+06      1
# AXE                          PoW           21000000     4.993031e+06      1
# TRVC                     PoW/PoS           82546564     3.692312e+07      0
# DTEM                         PoS           21000000     7.082392e+06      0
# GIC                      PoW/PoS            5151000     5.919490e+06      0
# PNY                          PoS        16880000000     1.042012e+06      0
# ABS                      PoW/PoS           52500000     1.333262e+07      0
# VITAE                        PoS          100000000     6.605388e+07      0
# HEX                          PoW           22105263     1.416663e+06      1
# TPC                      PoW/PoS         1000000000     5.403802e+06      0
# WEBC                         PoW         1750000000     1.558020e+07      1
# RYO                          PoW           88188888     4.890897e+06      1
# URALS                        PoW          210000000     1.474615e+07      1
# QWC                          PoW       184470000000     9.955311e+10      1
# ARE                          PoS           55000000     1.926951e+07      0
# EUNO                     PoW/PoS           50000000     3.077113e+07      0
# MMO                          PoS          260000000     1.077639e+08      0
# KETAN                        PoS          210000000     9.327132e+06      0
# PPAI                         PoW         2100000000     2.100000e+09      1
# XDNA                     PoW/PoS          366000000     4.672514e+06      0
# PAXEX                        PoS          100000000     4.504639e+06      0
# AZART                        PoW           25000000     5.015881e+06      1
# TSC                      PoW/PoS        18000000000     1.059954e+09      0
# KCASH       Zero-Knowledge Proof         1000000000     1.000000e+09      0
# XCG                          PoW          100000000     9.753754e+06      1
# AAC                         DPOS         1000000000     1.000000e+09      3
# CRYP                         PoW         7600000000     4.235112e+09      1
# BTXC                         PoS           50000000     6.787405e+06      0
# ACM                          PoW           84000000     1.363485e+07      1
# BSV                          PoW           21000000     1.799251e+07      1
# BITM                         Pos        70000000000     2.085159e+08      0
# JMC                          PoS                  0     1.720992e+10      0
# FRED                         PoW         8080000000     1.867055e+09      1
# HERB                     PoW/PoS           54000000     3.531219e+07      0
# UMO                          PoW       105120001.44     1.578281e+06      1
# LIT                          PoW           25228800     1.584672e+07      1
# PIRATE                       PoS          105000000     1.347592e+07      0
# EXO                          PoW           21000000     4.060919e+05      1
# BLTG                         PoW          120000000     3.528472e+07      1
# OWC                      PoW/PoS           21000000     1.477755e+07      0
# BEAM                         PoW          262800000     3.568752e+07      1
# GALI                     PoW/PoS           19035999     1.826501e+07      0
# BTH                          PoW           30886000     2.515079e+07      1
# CSPN                         PoS           13370000     1.934702e+06      0
# CREDIT                   PoW/PoS        74800000000     3.082571e+10      0
# SLC                          PoW          100000000     1.292579e+07      1
# DASHP                        PoS           19700000     7.156594e+05      0
# NSD                      PoW/PoS           84000000     2.054653e+07      0
# BEET                     PoW/PoS          500000000     1.989381e+08      0
# TTN                      PoW/PoS         5000000000     8.963612e+08      0
# AWR                      PoW/PoS          420000000     1.542023e+07      0
# BLAST                        PoW           64000000     5.229384e+07      1
# XRC                          PoW            2100000     1.170292e+06      1
# GLT                          PoW          168000000     8.461310e+07      1
# INSN                     PoW/PoS           30000000     2.377596e+07      0
# ALX                         DPoS         1000000000     1.000000e+09      0
# LDOGE                    PoW/PoS        35000000000     1.531889e+10      0
# SLR                          PoW        98100000000     5.556508e+07      1
# TRK                      PoW/PoS                  0     2.425741e+08      0
# UFO                          PoW         4000000000     3.824685e+09      1
# OC                       PoW/PoS          200000000     3.537150e+06      0
# BLC                          PoW         7000000000     2.335679e+07      1
# BITS                     PoW/PoS           54256119     2.057653e+07      0
# NEOS                         PoS           21000000     4.392258e+06      0
# HYPER                    PoW/PoS                  0     9.631200e+06      0
# PINK                     PoW/PoS          500000000     4.363536e+08      0
# CESC                         PoW         1000000000     7.802107e+08      1
# ADC                      PoW/PoS        10500000000     9.807325e+08      0
# NKA                      PoW/PoS          190000000     1.793973e+10      0
# PIGGY                    PoW/PoS         1000000000     4.942407e+08      0
# CRW                          PoW           42000000     2.298693e+07      1
# GEN                      PoW/PoS           15000000     6.000000e+07      0
# SMLY                         PoW        50000000000     2.958399e+10      1
# MI                       PoW/PoS          400000000     4.043165e+08      0
# GRS                          PoW          105000000     7.329820e+07      1
# CPC                      PoW/PoS          208000000     2.013643e+08      0
# CLUB                     PoW/PoS          160000000     1.036219e+08      0
# RADS                         PoS            9000000     3.821246e+06      0
# BTA                          PoW            5000000     5.052556e+06      1
# PAK                          PoW          182000000     6.968446e+07      1
# CRB               Proof of Trust           16504333     1.690102e+07      0
# OK                       PoW/PoS          105000000     7.467606e+07      0
# LSK                         DPoS          159918400     1.200121e+08      0
# XHI                          PoS        10008835635     1.000024e+10      0
# XWC                      PoW/PoS          300000000     2.520056e+08      0
# FSC                      PoW/PoS           60168145     1.120385e+06      0
# J                            PoW            2800000     3.332922e+06      1
# TRI                      PoW/PoS             120000     1.407778e+05      0
# VOLLAR                       PoW         2100000000     1.000000e+08      1
# EOS                         DPoS                  0     1.020545e+09      0
# RCC                          PoW           24487944     2.448794e+07      1
# OXY                         DPoS                  0     1.122382e+09      0
# TCH                          PoS         1000000000     1.000000e+09      0
# WAVES                       LPoS          100000000     1.000000e+08      0
# PART                         PoS            8634140     9.283138e+06      0
# BTT                         DPoS       990000000000     9.899887e+11      2
# NXT                     PoS/LPoS         1000000000     1.000000e+09      0
# ZEPH                        DPoS         2000000000     2.000000e+09      0
# GAP                      PoW/PoS          250000000     1.493105e+07      0
# BDX                          PoW         1400222610     9.802226e+08      1
# ZEN                          PoW           21000000     7.296538e+06      1
# XBC                          PoS            1000000     1.283270e+05      0

# %%
# Print the total number of tradable cryptocurrencies

print(f"The total number of tradable cryptocurrencies is:{len(clustered_df)}")
# Out:
# The total number of tradable cryptocurrencies is:532

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
columns = [ "TotalCoinSupply", "TotalCoinsMined"]
clustered_scaled = StandardScaler().fit_transform(clustered_df[columns])
print(clustered_scaled[0:5])
# Out:
# [[-0.1528703  -0.11710817]
#  [-0.145009   -0.09396955]
#  [ 4.48942416  0.52494561]
#  [-0.15255998 -0.11671506]
#  [-0.1528703  -0.11474682]]

# %%
#create a dataframe

columns = ["TotalCoinSupply", "TotalCoinsMined"]
scaled_df = pd.DataFrame(
    data=clustered_scaled,
    index=clustered_df.index
    ,columns=columns)

# %%
#include additional columns- "class" and "CoinName"
scaled_df[["CoinName", "class"]]=clustered_df[["CoinName", "class"]]
scaled_df.head()
# Out:
#             TotalCoinSupply  TotalCoinsMined   CoinName  class
# Unnamed: 0
# 42                -0.152870        -0.117108    42 Coin      0
# 404               -0.145009        -0.093970    404Coin      0
# 1337               4.489424         0.524946  EliteCoin      0
# BTC               -0.152560        -0.116715    Bitcoin      1
# ETH               -0.152870        -0.114747   Ethereum      1

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
source = scaled_df

alt.Chart(source).mark_circle(size=60).encode(
    x="TotalCoinsMined:Q",
    y="TotalCoinSupply:Q",
    color='class:N',
    tooltip=['CoinName']
    
    
).interactive()
# Out:
# alt.Chart(...)

# %%
# Delete Amazon SageMaker
